# %%
vector = []
vector.appened (8)
vector.appened (9)
vector.appened (11)
print (vector)
print (vector = [0])
print (vector = [1])
print (vector = [2])
print (vector = [-1])
print (vector = [-2])
print (vector = [-3])

# %%
vector2 = [3,4,56,"Luis"]
print (vector2)

# %%
vector2.insert (1, "Managua")
print (vector2)

# %%
for item in vector2:
    print (item)

# %%
for i in range (4):
    print (vector2 [index])
